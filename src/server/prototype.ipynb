# %%
# ---------- Imports ---------- #
from pydantic import BaseModel, Field
from typing import List, Dict
import urllib.request
import itertools
import json

# %%
# ---------- Request and response models ---------- #
class OrderDetails(BaseModel):
    garmentType: str = Field(..., examples=["Shirt", "Pants"])
    material: str = Field(..., examples=["Cotton", "Polyester"])
    unitWeight: float = Field(..., gt=0, examples=[0.30, 1.20])
    size: str = Field(..., examples=["XS", "S", "M", "L", "XL"])
    collection: str = Field(..., examples=["Summer", "Winter"])

class PackagingConfigurations(BaseModel):
    unitsPerPackage: int = Field(..., gt=0, examples=[1, 5, 10])
    foldingMethod: str = Field(..., examples=["Method1", "Method2"])
    layout: str = Field(..., examples=["LayoutA", "LayoutB"])
    supplier: str = Field(..., examples=["SupplierA", "SupplierB"])

# %%
# ---------- Helper functions ---------- #
def build_request_data(orderDetails: OrderDetails):
    COLUMNS = [
        "SupplierName", "GarmentType", "Material", "Weight",
        "ProposedUnitsPerCarton", "ProposedFoldingMethod",
        "ProposedLayout", "Size", "Collection"
    ]

    GARMENT_TYPE = orderDetails.garmentType
    MATERIAL = orderDetails.material
    WEIGHT = orderDetails.unitWeight
    SIZE = orderDetails.size
    COLLECTION = orderDetails.collection


    FOLDING_METHODS = ["Method1", "Method2", "Method3"]
    LAYOUTS = ["LayoutA", "LayoutB", "LayoutC", "LayoutD", "LayoutE"]
    UNITS_RANGE = list(range(5, 50, 5))
    SUPPLIERS = [
        "SupplierA", "SupplierB", "SupplierC", "SupplierD",
        "SupplierE", "SupplierF", "SupplierG", "SupplierH"
    ]

    data_rows = [
        [
            supplier,
            GARMENT_TYPE,
            MATERIAL,
            WEIGHT,
            units,
            folding,
            layout,
            SIZE,
            COLLECTION,
        ]
        for supplier, units, folding, layout in itertools.product(
            SUPPLIERS,
            UNITS_RANGE,
            FOLDING_METHODS,
            LAYOUTS,
        )
    ]

    request_data = {
        "input_data": {
            "index": [0, 1],
            "columns": COLUMNS,
            "data": data_rows,
        }
    }

    return request_data



def execute_request(body):
    url = 'https://pckg-quality-endpoint.eastus.inference.ml.azure.com/score'
    
    api_key = ''
    if not api_key:
        raise Exception("A key should be provided to invoke the endpoint")


    headers = {'Content-Type':'application/json', 'Accept': 'application/json', 'Authorization':('Bearer '+ api_key)}

    req = urllib.request.Request(url, body, headers)

    try:
        response = urllib.request.urlopen(req)

        return response
    except urllib.error.HTTPError as error:
        print("The request failed with status code: " + str(error.code))

        # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
        print(error.info())
        print(error.read().decode("utf8", 'ignore'))

def to_packaging_config(packaging_detail: List) -> PackagingConfigurations:
    supplier, _, _, _, units, folding, layout, *_ = packaging_detail
    return PackagingConfigurations(
        unitsPerPackage=units,
        foldingMethod=folding,
        layout=layout,
        supplier=supplier
    )


def build_configurations(request_data, result) -> List[PackagingConfigurations]:
    packaging_details = request_data["input_data"]["data"]

    packaging_details_enriched = [order + [score]
                for order, score in zip(packaging_details, result)]
        
    best_overall = max(packaging_details_enriched, key=lambda r: r[-1])

    best_per_supplier: Dict[str, List] = {}
    for detail in packaging_details_enriched:
        supplier, *_, score = detail
        if supplier not in best_per_supplier or score > best_per_supplier[supplier][-1]:
            best_per_supplier[supplier] = detail

    configs: List[PackagingConfigurations] = []
    configs.append(to_packaging_config(best_overall))

    for entry in best_per_supplier.values():
        configs.append(to_packaging_config(entry))

    return configs

# %%
data = OrderDetails(
    garmentType="Shirt",
    material="Polyester",
    unitWeight=0.16,
    size="L",
    collection="Summer"
)

# %%
request_data = build_request_data(data)
request_data
# Out:
# {'input_data': {'index': [0, 1],
#   'columns': ['SupplierName',
#    'GarmentType',
#    'Material',
#    'Weight',
#    'ProposedUnitsPerCarton',
#    'ProposedFoldingMethod',
#    'ProposedLayout',
#    'Size',
#    'Collection'],
#   'data': [['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierA',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierB',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierC',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutB',
# ...
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     25,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     30,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     35,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     40,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierG',
#     'Shirt',
#     'Polyester',
#     0.16,
#     45,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     5,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     10,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     15,
#     'Method3',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method1',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutA',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutB',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutC',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutD',
#     'L',
#     'Summer'],
#    ['SupplierH',
#     'Shirt',
#     'Polyester',
#     0.16,
#     20,
#     'Method2',
#     'LayoutE',
#     'L',
#     'Summer'],
#    ...]}}

# %%
body = str.encode(json.dumps(request_data))
body
# Out:
# b'{"input_data": {"index": [0, 1], "columns": ["SupplierName", "GarmentType", "Material", "Weight", "ProposedUnitsPerCarton", "ProposedFoldingMethod", "ProposedLayout", "Size", "Collection"], "data": [["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method1", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method1", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method1", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method1", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method1", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method2", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method2", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method2", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method2", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method2", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method3", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method3", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method3", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method3", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 5, "Method3", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method1", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method1", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method1", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method1", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method1", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method2", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method2", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method2", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method2", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method2", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method3", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method3", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method3", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method3", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 10, "Method3", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method1", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method1", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method1", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method1", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method1", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method2", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method2", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method2", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method2", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method2", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method3", "LayoutA", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method3", "LayoutB", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method3", "LayoutC", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method3", "LayoutD", "L", "Summer"], ["SupplierA", "Shirt", "Polyester", 0.16, 15, "Method3", "LayoutE", "L", "Summer"], ["SupplierA", "Shirt", "Polyester" ...

# %%
response = execute_request(body)
response

# %%
result = json.loads(response.read())
result
# Out:
# [0.8531564849842795,
#  0.8527787105607668,
#  0.8957827639291442,
#  0.8771591439314597,
#  0.832663101455652,
#  0.8755177802540264,
#  0.8816778069363652,
#  0.9353826409854317,
#  0.9192738753959642,
#  0.8649934597812511,
#  0.8816256505135615,
#  0.8794148685868287,
#  0.9167937751907068,
#  0.901512011115606,
#  0.8615546363353995,
#  0.8445801493558043,
#  0.844184340771244,
#  0.8914998638967528,
#  0.872220064478448,
#  0.8050867882201559,
#  0.8762215418335235,
#  0.8823514224869108,
#  0.933452868705103,
#  0.9169057577769292,
#  0.863296725027191,
#  0.8871546255777173,
#  0.8850336384362296,
#  0.9224024066197161,
#  0.908047415300732,
#  0.864715279073722,
#  0.8383186655178901,
#  0.8486545802774255,
#  0.8865355337334098,
#  0.8760041203923764,
#  0.8109461543319932,
#  0.6455218579981211,
#  0.5773307087358592,
#  0.5792630153775429,
#  0.5856404731986071,
#  0.7244908679598013,
#  0.6374021298115002,
#  0.5743379134437554,
#  0.5701925807868384,
#  0.5779158816045159,
#  0.702053712817207,
#  0.6125905659600348,
#  0.5662998683806105,
#  0.5899071181012155,
#  0.5979903509805319,
#  0.7492705183168784,
#  0.6455007857247992,
#  0.581523780159603,
#  0.5878137232082986,
#  0.5945232985602168,
#  0.741754282176167,
#  0.6369585130226137,
#  0.5780934997448743,
#  0.5990432436524845,
#  0.6069728644208733,
#  0.7483193953168379,
#  0.6318015021337362,
#  0.5904455261892627,
#  0.38771892662688423,
#  0.42699930079199827,
#  0.5434679278441501,
#  0.5212696457679685,
#  0.4010407612452068,
#  0.3652859866734165,
#  0.42434782590608777,
#  0.536122298653191,
#  0.5035007396950971,
#  0.40035436664903495,
#  0.33416126862114515,
#  0.37264219133225657,
#  0.512861867072433,
#  0.4635065997644344,
#  0.3465960978956518,
#  0.35006406994624656,
#  0.38827985792450515,
#  0.5034668870989968,
#  0.48118039198775575,
#  0.36802829918500574,
#  0.32480669831927017,
#  0.38131474110787683,
#  0.491430829666768,
#  0.4588388097901152,
#  0.3633227878541987,
#  0.2983878140693237,
#  0.3348771706767091,
#  0.47156801963226347,
#  0.4227381067136068,
#  0.31490082749002724,
#  0.3944712352715478,
#  0.4617295901151334,
#  0.5382626569443848,
#  0.5113635164323829,
#  0.39027380843784537,
#  0.36448284260436453,
#  0.45085983263336327,
#  0.5372412450120988,
#  0.4853454800248566,
#  0.3820537096838655,
#  0.33119199519815545,
#  0.3957860011882481,
#  0.5007492213888657,
#  0.46221684291250204,
#  0.3444701301002092,
#  0.3894627722757724,
#  0.4512375713398251,
#  0.528543913016019,
#  0.5105353439352895,
#  0.3894854292212043,
#  0.36019228288578714,
#  0.4410153918251493,
#  0.5281292485546983,
#  0.4851283674097258,
#  0.38184852051210066,
#  ...]

# %%
configurations = build_configurations(request_data, result)
configurations
# Out:
# [PackagingConfigurations(unitsPerPackage=45, foldingMethod='Method2', layout='LayoutC', supplier='SupplierA'),
#  PackagingConfigurations(unitsPerPackage=45, foldingMethod='Method2', layout='LayoutC', supplier='SupplierA'),
#  PackagingConfigurations(unitsPerPackage=45, foldingMethod='Method3', layout='LayoutC', supplier='SupplierB'),
#  PackagingConfigurations(unitsPerPackage=45, foldingMethod='Method3', layout='LayoutC', supplier='SupplierC'),
#  PackagingConfigurations(unitsPerPackage=5, foldingMethod='Method1', layout='LayoutC', supplier='SupplierD'),
#  PackagingConfigurations(unitsPerPackage=5, foldingMethod='Method1', layout='LayoutC', supplier='SupplierE'),
#  PackagingConfigurations(unitsPerPackage=45, foldingMethod='Method1', layout='LayoutC', supplier='SupplierF'),
#  PackagingConfigurations(unitsPerPackage=5, foldingMethod='Method1', layout='LayoutC', supplier='SupplierG'),
#  PackagingConfigurations(unitsPerPackage=5, foldingMethod='Method1', layout='LayoutC', supplier='SupplierH')]
